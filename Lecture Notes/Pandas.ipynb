# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 91.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 104.9 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
s = pd.Series([1,3,4,5], index=[[10,20],30,40,50])
print(s)
# Out:
# [10, 20]    1
# 30          3
# 40          4
# 50          5
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
independece = {'USA': 'Washington, D.C.',
               'Canada': 'Ottawa',
               'UK': 'London',
               'France': 'Paris'}
pd.Series(independece)
# Out:
# USA       Washington, D.C.
# Canada              Ottawa
# UK                  London
# France               Paris
# dtype: object

# %%
import numpy as np
arr = np.array([[10, 20], [10, 5]])  # nested lists -> 2x2 array
print(arr.shape)
arr
pd.DataFrame(arr, columns=['Column1', 'Column2'], index=['Row1', 'Row2'])
# Out:
# (2, 2)
#       Column1  Column2
# Row1       10       20
# Row2       10        5

# %%
dict_data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
             'Age': [24, 27.0, np.nan, 32],
             'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}     
pd.DataFrame(dict_data)
# Out:
#       Name   Age         City
# 0    Alice  24.0     New York
# 1      Bob  27.0  Los Angeles
# 2  Charlie   NaN      Chicago
# 3    David  32.0      Houston

# %%
a =pd.DataFrame(dict_data, columns=['Name', 'Age'])

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 196.0+ bytes

# %%
import pandas as pd

print(f"Pandas version: {pd.__version__}")
data = pd.read_csv('your_data.csv')
print(data.head())
# Out:
# Pandas version: 2.3.3
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       3 print(f"Pandas version: {pd.__version__}")
# ----> 4 data = pd.read_csv('your_data.csv')
#       5 print(data.head())
#
# ...
